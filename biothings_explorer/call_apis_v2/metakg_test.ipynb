# %%
import logging
import sys
from pprint import pprint

import httpx


sys.path.append(
    "/Users/cwu/prj2/bte-py"
)  # TODO: set correct path to bte-py project, so we can import its modules.

from biothings_explorer.call_apis_v2.query import SmartAPI
from biothings_explorer.call_apis_v2.query_validator import InvalidQuery

logging.getLogger("urllib3").setLevel(logging.ERROR)
logging.getLogger("httpx").setLevel(logging.ERROR)
# logging.basicConfig(filename="myapp.log", level=logging.INFO, filemode="w")
logger = logging.getLogger(__name__)

# %%
smart_api = SmartAPI(
    "https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/mygene.info/openapi_full.yml"
)

# smart_api = SmartAPI("https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/semmeddb/smartapi.yaml")
# smart_api = SmartAPI("https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/dgidb/openapi.yml")
# smart_api = SmartAPI("https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/biothings_foodb/smartapi.yaml")
# smart_api = SmartAPI("https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/ddinter/ddinter.yaml")
# smart_api = SmartAPI("https://raw.githubusercontent.com/NCATS-Tangerine/translator-api-registry/master/pfocr/smartapi.yaml")

# smart_api = SmartAPI("http://www.smart-api.info/api/metadata/e8818d98f59fb98ad5ba6e4637b5dec4")

mkg_edges = smart_api.list_metakg()

# %%
no_of_nodes = len(
    set([edge["subject"] for edge in mkg_edges])
    | set([edge["object"] for edge in mkg_edges])
)
no_of_predicates = len(set([edge["predicate"] for edge in mkg_edges]))
print(f"Number of MetaKG nodes: {no_of_nodes}")
print(f"Number of MetaKG predicates: {no_of_predicates}")
print(f"Number of MetaKG edges: {len(mkg_edges)}")
# Out:
# Number of MetaKG nodes: 6
# Number of MetaKG predicates: 8
# Number of MetaKG edges: 18

# %%
test_mkgedge = mkg_edges[0]
pprint(test_mkgedge)
# Out:
# {'bte': {'query_operation': {'method': 'post',
#                              'params': {'fields': 'entrezgene',
#                                         'size': 1000,
#                                         'species': 'human'},
#                              'path': '/query',
#                              'request_body': {'body': {'q': '{{ queryInputs }}',
#                                                        'scopes': 'pathway.reactome.id'}},
#                              'server': 'https://mygene.info/v3',
#                              'support_batch': True},
#          'response_mapping': {'has_participant': {'NCBIGene': 'entrezgene'}}},
#  'object': 'Gene',
#  'predicate': 'has_participant',
#  'subject': 'Pathway'}

# %%
test_ids = ["R-HSA-69306", "R-HSA-6798695"]
res = smart_api.get_edge(test_mkgedge, test_ids[0])
cnt = 0
ids_test_edge = set()
for edge in res:
    pprint(edge)
    cnt += 1
    ids_test_edge.add(edge["object"]["NCBIGene"])
print(f"Number of edges retrieved: {cnt}")
# Out:
# {'object': {'NCBIGene': '23633', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51659', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '64785', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9837', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '84296', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '81620', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8318', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '29935', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '990', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4176', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4172', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4173', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4171', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4175', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4174', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10926', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '55388', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23595', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4999', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5001', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5000', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23594', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51053', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '84515', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4998', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8317', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23649', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5557', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5558', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5422', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2237', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '56655', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '54107', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5426', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5427', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51343', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3836', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3978', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9134', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5981', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10714', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '57804', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5425', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6502', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '119504', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '25906', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5424', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10393', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '29945', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51433', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8881', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '29882', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '246184', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8697', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '996', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '64682', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51529', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1763', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '898', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '11065', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '27338', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3837', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5985', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5982', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5984', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5983', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7324', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '890', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5111', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8900', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1017', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3020', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3021', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6118', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6119', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6117', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7321', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '474382', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9978', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '55766', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '94239', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '126961', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '333932', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '653604', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8351', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8356', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8350', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8352', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8353', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8354', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8355', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8357', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8358', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8968', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3014', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6500', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '102724334', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8454', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3013', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3012', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '723790', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8331', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8335', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8337', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8334', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8338', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '554313', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8359', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8362', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8366', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8294', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8341', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8360', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8361', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8367', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8368', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8370', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8365', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8363', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8364', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '121504', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3017', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '255626', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3018', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8339', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8342', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8343', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8344', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8345', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8346', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8348', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '85236', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8970', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8340', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8347', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8349', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '128312', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '122706', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23198', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '143471', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9861', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5689', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5717', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5695', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5709', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5713', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5686', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5701', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5702', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5708', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5719', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5718', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5683', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5707', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10197', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5691', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5699', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5690', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5720', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5682', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5687', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5688', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5693', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5714', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9491', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5684', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5685', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5715', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5711', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5716', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5692', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5694', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5710', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5705', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5704', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5698', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5706', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5721', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10213', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5700', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5696', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7979', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6233', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7311', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7314', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7316', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# Number of edges retrieved: 186

# %%
# Let's verify the results by call APIs directly
url = f"https://mygene.info/v3/query?q=pathway.reactome.id:{test_ids[0]}&species=human&fields=entrezgene&size=500"
resp = httpx.get(url).json()
ids_mygene = set([x["entrezgene"] for x in resp["hits"]])
len(ids_mygene), len(ids_test_edge), ids_mygene == ids_test_edge
# Out:
# (186, 186, True)

# %%
res = smart_api.get_edges(test_mkgedge, test_ids)
cnt = 0
ids_test_edge = set()
for edge in res:
    pprint(edge)
    cnt += 1
    ids_test_edge.add(edge["object"]["NCBIGene"])
print(f"Number of edges retrieved: {cnt}")
# Out:
# {'object': {'NCBIGene': '10043', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '11322', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10321', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '150372', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10394', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10562', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5273', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '114790', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '11333', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '80301', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '127829', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10875', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '124583', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1774', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1992', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '22875', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23317', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2352', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23593', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '26578', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4033', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6993', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '79169', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51646', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '55313', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '154664', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '57826', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6317', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '25798', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '374395', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9145', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '55', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '199675', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5787', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6590', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8288', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '83716', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '29952', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5036', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '56954', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '64114', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '84418', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '387921', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '388698', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '83858', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '932', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '84443', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '84514', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9725', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7130', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '387263', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '388697', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8836', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5553', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '56888', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5799', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5912', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '89777', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23071', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23406', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '25797', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '25801', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '84766', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8635', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4332', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9522', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '55754', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '201294', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1476', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '175', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23218', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2896', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '57020', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '116844', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5284', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6036', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8804', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '160364', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2204', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '222487', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '22918', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '258010', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '25840', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '54918', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6282', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '441864', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9535', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '963', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '968', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1116', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5806', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6286', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10493', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10857', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '79930', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9961', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1654', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '566', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3916', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10549', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23601', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '100049587', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8993', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6037', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '820', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1084', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '11314', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '11240', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '965', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '170482', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '338339', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8778', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '945', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '107987462', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '102725035', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6278', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51816', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5269', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '27180', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3903', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4353', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '11026', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '101', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10120', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10288', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '81619', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '126014', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5328', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4973', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1667', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3240', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8972', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10396', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '728358', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1118', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1823', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '29099', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1669', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '671', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '79895', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51071', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51719', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '64386', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23412', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5547', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '326624', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '327', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '53917', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '55276', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23200', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23250', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4069', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51316', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51806', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4125', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4126', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '383', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '210', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10075', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10159', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7077', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23352', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '290', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2215', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6518', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '401258', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8514', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9545', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10326', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '26', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5005', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1088', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '11010', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '12', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5004', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2519', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '25852', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2665', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '57126', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8566', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4680', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '51411', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '54472', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '374403', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8895', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9342', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9588', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5834', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5836', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4317', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '94103', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3101', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3310', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6402', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5211', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8904', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '178', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10577', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '121260', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1512', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '221', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '272', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '353189', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5023', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '84329', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '84658', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8560', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '967', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '976', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9761', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '978', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '53831', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3608', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7226', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10555', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1471', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '158747', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2219', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '230', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '80142', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '93100', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4257', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '54509', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '55832', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3848', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '56729', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5049', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2760', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8621', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23197', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2444', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4718', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5223', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6836', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2717', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10855', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1265', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '81567', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '47', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5329', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6947', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '654364', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '140885', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6727', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2517', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7133', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3920', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4311', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4831', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1727', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '11031', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8876', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23526', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1675', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6793', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '64333', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '53916', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5657', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9798', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4282', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '80331', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6556', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '683', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5645', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1378', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8694', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5315', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '28988', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3687', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '197', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9218', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '634', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '57153', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3482', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3577', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5317', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5768', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '961', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3579', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5788', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '79888', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10487', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2512', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '535', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1508', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3684', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10788', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '226', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '410', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '427', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '728', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2548', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2358', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '353', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3934', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8987', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2495', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1143', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '302', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5175', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2821', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2934', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '684', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '4057', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '58485', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '22931', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '138050', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2588', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '196527', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2171', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10890', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10450', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5795', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '2950', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3958', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '1315', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10970', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3683', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23114', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3689', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-6798695', 'type': 'Pathway'}}
# ...
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9978', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '55766', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '94239', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '126961', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '333932', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '653604', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8351', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8356', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8350', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8352', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8353', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8354', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8355', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8357', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8358', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8968', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6500', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3014', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '102724334', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8454', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '723790', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8331', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8335', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8337', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3012', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8334', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8338', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3013', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8294', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8341', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8360', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8361', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8367', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8368', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8370', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '554313', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8359', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8362', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8366', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8363', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8364', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8365', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '121504', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3017', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8339', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8342', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8343', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8344', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8345', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8346', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8348', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '3018', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8970', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8340', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8347', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '85236', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '255626', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '8349', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '128312', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '122706', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '23198', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '143471', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9861', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5689', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5717', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5695', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5709', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5713', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5686', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5701', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5702', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5708', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5719', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5718', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5683', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5707', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10197', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5691', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5699', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5690', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5720', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5682', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5687', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5688', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5693', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5714', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '9491', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5684', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5685', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5715', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5711', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5716', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5692', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5694', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5710', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5705', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5704', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5698', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5706', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5721', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '10213', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5700', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '5696', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7979', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '6233', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7311', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7314', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# {'object': {'NCBIGene': '7316', 'type': 'Gene'},
#  'predicate': {'type': 'has_participant'},
#  'subject': {'_id': 'R-HSA-69306', 'type': 'Pathway'}}
# Number of edges retrieved: 666

# %%
# Let's verify the results by call APIs directly
url = "https://mygene.info/v3/query"
params = {
    "q": test_ids,
    "scopes": "pathway.reactome.id",
    "species": "human",
    "fields": "entrezgene",
    "size": 1000,
}
resp = httpx.post(url, json=params).json()
ids_mygene = set([x["entrezgene"] for x in resp])
len(ids_mygene), len(ids_test_edge), ids_mygene == ids_test_edge
# Out:
# (650, 650, True)
